# %%
import tensorflow as tf
from tensorflow.keras import datasets
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D,MaxPooling2D,Dense,Flatten,Dropout
from tensorflow.keras.applications import VGG16

# %%
(x_train,y_train),(x_test,y_test)=tf.keras.datasets.mnist.load_data()

# %%
x_train=x_train.reshape(-1,28,28,1)
x_test=x_test.reshape(-1,28,28,1)
y_train=y_train.reshape(len(y_train),1)
y_test=y_test.reshape(len(y_test),1)

# %%
x_train=x_train/255.0
x_test=x_test/255.0

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (60000, 28, 28, 1)
# (10000, 28, 28, 1)
# (60000, 1)
# (10000, 1)

# %%
model = Sequential([
    Conv2D(32,(3,3),activation="relu",input_shape=(28,28,1)),
    MaxPooling2D(2,2),
    Conv2D(64,(3,3),activation="relu"),
    MaxPooling2D(2,2),
    Flatten(),
    Dense(128,activation="relu"),
    Dropout(0.5),
    Dense(10,activation="softmax")
])

# %%
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)
from tensorflow.keras.callbacks import EarlyStopping
early_stop=EarlyStopping(
    monitor="val_loss",
    patience=5,
    restore_best_weights=True
)

# %%
history = model.fit(x_train,y_train,epochs=5,validation_data=(x_test,y_test),batch_size=64,callbacks=[early_stop])
# Out:
# Epoch 1/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 33s 35ms/step - accuracy: 0.9052 - loss: 0.3052 - val_accuracy: 0.9537 - val_loss: 0.1491
# Epoch 2/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 35s 37ms/step - accuracy: 0.9189 - loss: 0.2667 - val_accuracy: 0.9608 - val_loss: 0.1239
# Epoch 3/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 33s 35ms/step - accuracy: 0.9270 - loss: 0.2403 - val_accuracy: 0.9648 - val_loss: 0.1144
# Epoch 4/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 41s 35ms/step - accuracy: 0.9330 - loss: 0.2201 - val_accuracy: 0.9668 - val_loss: 0.1027
# Epoch 5/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 34s 36ms/step - accuracy: 0.9403 - loss: 0.2001 - val_accuracy: 0.9699 - val_loss: 0.0932

# %%
loss,accuracy=model.evaluate(x_test,y_test)
print("Accuracy",accuracy)
print("Loss",loss)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9699 - loss: 0.0932
# Accuracy 0.9699000120162964
# Loss 0.09317544847726822

# %%
prediction=model.predict(x_test)
print("Predicted Digit:",prediction[5].argmax())
print("Actual Digit:",y_test[5])
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step
# Predicted Digit: 1
# Actual Digit: [1]
